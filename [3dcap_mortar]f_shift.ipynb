# %%
import pandas as pd

excel_file = 'freq_shift_3dcap_mortar.xlsx'
shift = pd.read_excel(excel_file)

shift.head()


sixtyk = pd.read_excel(excel_file, sheet_name=0)
sixtyk.head()
# Out:
#    time(min)  frequency(Hz)  percent_f_shift
# 0          0        60790.0         0.000000
# 1         30        61850.0         1.743708
# 2         60        62400.0         2.648462
# 3         90        63450.0         4.375720
# 4        120            NaN              NaN

# %%
shift_sixtyk = sixtyk[['time(min)','percent_f_shift']]

shift_sixtyk.head()
# Out:
#    time(min)  percent_f_shift
# 0          0         0.000000
# 1         30         1.743708
# 2         60         2.648462
# 3         90         4.375720
# 4        120              NaN

# %%
sixtyk = pd.read_excel(excel_file, sheet_name=0)
# del epoxy2['frequency(Hz)']
sixtyk.dropna(inplace = True)
print(sixtyk)
# Out:
#    time(min)  frequency(Hz)  percent_f_shift
# 0          0        60790.0         0.000000
# 1         30        61850.0         1.743708
# 2         60        62400.0         2.648462
# 3         90        63450.0         4.375720

# %%
oneEightyk = pd.read_excel(excel_file, sheet_name=1)
# del epoxy2['frequency(Hz)']
oneEightyk.dropna(inplace = True)
print(oneEightyk)
# Out:
#    time(min)  frequency(Hz)  percent_f_shift
# 0          0         182050         0.000000
# 1         30         182500         0.247185
# 3         90         182450         0.219720
# 4        120         183100         0.576765

# %%
twoFiftyk = pd.read_excel(excel_file, sheet_name=2)
# del epoxy2['frequency(Hz)']
twoFiftyk.dropna(inplace = True)
print(twoFiftyk)
# Out:
#    time(min)  frequency(Hz)  percent_f_shift
# 0          0         253850         0.000000
# 1         30         254700         0.334843
# 2         60         255150         0.512113
# 3         90         255300         0.571203
# 4        120         255550         0.669687

# %%
threeSixtyk = pd.read_excel(excel_file, sheet_name=3)
# del epoxy2['frequency(Hz)']
threeSixtyk.dropna(inplace = True)
print(threeSixtyk)
# Out:
#    time(min)  frequency(Hz)  percent_f_shift
# 0          0         361300         0.000000
# 1         30         361800         0.138389
# 2         60         361500         0.055356
# 3         90         362000         0.193745
# 4        120         361800         0.138389

# %%
fourTenk = pd.read_excel(excel_file, sheet_name=4)
# del epoxy2['frequency(Hz)']
fourTenk.dropna(inplace = True)
print(fourTenk)
# Out:
#    time(min)  frequency(Hz)  percent_f_shift
# 0          0         414800         0.000000
# 1         30         415250         0.108486
# 2         60         415700         0.216972
# 3         90         416350         0.373674
# 4        120         416600         0.433944

# %%
fourFiftyk = pd.read_excel(excel_file, sheet_name=5)
# del epoxy2['frequency(Hz)']
fourFiftyk.dropna(inplace = True)
print(fourFiftyk)
# Out:
#    time(min)  frequency(Hz)  percent_f_shift
# 0          0         455650         0.000000
# 1         30         456050         0.087787
# 2         60         455750         0.021947
# 3         90         456700         0.230440
# 4        120         456550         0.197520

# %%
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

import matplotlib as mp
from matplotlib import cm
import seaborn as sns

sns.set(style="whitegrid") # make background white colored 

fig = plt.figure(figsize = (6,4), dpi=300) # set figure size and resolution

tickfont = {'family' : 'DejaVu Sans', 'size'   : 12}
labelfont = {'family' : 'DejaVu Sans', 'size'   : 8}

ax = plt.gca()


# sixtyk.plot(x='time(min)', y ='percent_f_shift', style = 's', linestyle = '--', ax = ax, label = '60k')

oneEightyk.plot(x='time(min)', y ='percent_f_shift', style = 's', linestyle = '--', ax = ax, label = '180k')

twoFiftyk.plot(x='time(min)', y ='percent_f_shift', style = 's', linestyle = '--', ax = ax, label = '250k')

threeSixtyk.plot(x='time(min)', y ='percent_f_shift', style = 's', linestyle = '--', ax = ax, label = '360k')

fourTenk.plot(x='time(min)', y ='percent_f_shift', style = 's', linestyle = '--', ax = ax, label = '410k')

fourFiftyk.plot(x='time(min)', y ='percent_f_shift', style = 's', linestyle = '--', ax = ax, label = '450k')


plt.ylabel("Frequency shift(%)")

plt.xlabel("Time (minutes)")

plt.xticks([0,30,60, 90, 120])

plt.show()
